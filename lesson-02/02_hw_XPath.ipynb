# %% [markdown]
# `GB` BigData / [Олег Гладкий](https://gb.ru/users/3837199) // домашнее задание

# %% [markdown]
# `262698` __Методы сбора и обработки данных из сети Интернет__:  `02`. Парсинг даных: HTML, DOM, __XPath__

# %% [markdown]
# ## Задание 1. XPath. Лента.РУ

# %% [markdown]
# Написать приложение или функцию, которые собирают основные новости с сайта на выбор:
#  * lenta.ru,
#  * yandex-новости.
#
# Для парсинга использовать `XPath`. Структура данных в виде словаря должна содержать:
# - *название источника;
# - наименование новости;
# - ссылку на новость;
# - дата публикации.
#
# Минимум один сайт, максимум — все два

# %%
import pandas as pd
from pprint import pprint 
import datetime

import requests
from lxml import html

# %% [markdown]
# ### Забираем все данные с сайта `Lenta.ru`

# %% [markdown]
#  Обращаемся к сайту как Хром методом `get` модуля `requests`. Кроме того:
#  * необходимо запомнить дату текущего запроса
#  * время этого текущего запроса
#  * для продолжения работы необходимо уточнить код ответа сервера `status_code`
#  * а так же необходимо уточнить, вернул ли нам сервер данные в формате `html`, информцию об этом сервер возвращает в заголовках `headers` в параметре `'Content-Type'`

# %%
# %%time
url = 'https://lenta.ru/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
}

response = requests.get(url=url, headers=headers)

news_date = str(datetime.date.today())
news_time = str(datetime.datetime.now().strftime("%H:%M"))

response.status_code, response.headers['Content-Type'], response.url,
# Out:
# Wall time: 80.1 ms
# (200, 'text/html; charset=utf-8', 'https://lenta.ru/')

# %% [markdown]
# #### Перобразуем данные к формату `DOM`

# %% [markdown]
# Преобразование тела документа как строки в ответе `response.text` в _дерево_ `DOM` при помощи метода `fromstring` модуля `html`

# %%
dom = html.fromstring(response.text)

# %% [markdown]
# ### Парсим
# Выберем из дерева `DOM` только блоки с новостями. Каждый такой блок новостей — это объект. Все объекты объеденены в список `list`. При этом самым верхним уровнем в структуре для такого объекта будет не начало сайта или дерева `DOM`, а начало этого информационного блока — тэг `a`.

# %% [markdown]
# #### Функция
# Фукнция для выборки парснутых данных в новостные элементы

# %%
def eject(elements):
    ''' забираем первый элемент из списка'''
    if isinstance(elements, list):
        if len(elements) == 1 or len(elements) > 1:
            element = str(elements[0])
        else:
            element = None
    return element

# %% [markdown]
# #### Блоки МИНИ
# Класс `card-mini__title` с минимальными новостями из нашего `DOM` в виде списка объектов:
# * Название новости
# * Ссылку
# * Время на текущий день.
#     - Новостной блок не содержит дату, а только время. Но мы располагаем датой запроса этих новостей, которую мы сохранили сразу после запроса в переменной `news_date`.
#     - Если время отсутствует в блоке с новостью, то воспользуемся временем запроса к сайту, сохранённого в переменной `news_time`.

# %% [markdown]
# __Блоки МИНИ__: все объекты с минимальными новостями

# %%
news_mini = dom.xpath('.//a[contains(@class, "card-mini")]')
print(f"Блоки МИНИ: количество: {len(news_mini)}")
# Out:
# Блоки МИНИ: количество: 89

# %% [markdown]
# __Блоки МИНИ__: Парсим данные для кадой новости и сохраняем их как строку `DataFrame`.

# %%
news_mini_table = pd.DataFrame(columns=['Name', 'Link', 'Date', 'Source', 'N_Type']) # инициализирум выходную таблицу
news_type = "mini"

for i in news_mini:
    name = eject(i.xpath('.//div[contains(@class, "card-mini__text")]/span[contains(@class, "card-mini__title")]/text()'))
    link = url.strip('/') + eject(i.xpath('.//@href'))
    time = eject(i.xpath('.//div[contains(@class, "card-mini__text")]/div[contains(@class, "card-mini__info")]/time[contains(@class, "card-mini__date")]/text()'))
    
    date = news_date + ';' + (time if time else news_time) 

    news_mini_table = news_mini_table.append({'Date': date, 'Name': name, 'Link': link, 'N_Type': news_type}, ignore_index=True)

print(f"НОВОСТИ МИНИ: {len(news_mini_table)} позиция распарсена")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# news_mini_table
# Out:
# НОВОСТИ МИНИ: 89 позиция распарсена

# %% [markdown]
# #### Блоки БИГ
# Новостные блоки БИГ: класс объектов `card-mini__big` с расширенными новостями из нашего `DOM` в виде 2-ого списка `list`.

# %%
news_big = dom.xpath('.//a[contains(@class, "card-big")]')
print(f"Блоки БИГ, количество: {len(news_big)} объекта получено")
# Out:
# Блоки БИГ, количество: 53 объекта получено

# %%
news_big_table = pd.DataFrame(columns=['Name', 'Link', 'Date', 'Source', 'N_Type'], index=[]) # инициализирум выходную таблицу
news_type = "BIG"

for i in news_big:
    title = eject(i.xpath('.//div[contains(@class, "card-big__titles")]/h3[contains(@class, "card-big__title")]/text()'))
    notes = eject(i.xpath('.//div[contains(@class, "card-big__titles")]/span[@class]/text()'))
    time =  eject(i.xpath('.//div[contains(@class, "card-big__info")]/time[contains(@class, "card-big__date")]/text()'))
    link =  eject(i.xpath('.//@href'))
    src =   eject(i.xpath('.//div[contains(@class, "card-big__info")]/div/svg/use/@href'))   # xlink:href="#ui-label_motor"

    name  = title + (notes if notes else "")
    date = time
    link = url.strip("/") + link
    
    news_big_table = news_big_table.append({'Name': name, 'Link': link, 'Date': date, 'N_Type': news_type}, ignore_index=True)

    
print(f"НОВОСТИ БИГ: {len(news_big_table)} позиция распарсена")
# news_big_table
# Out:
# НОВОСТИ БИГ: 53 позиция распарсена

# %% [markdown]
# ### ВСЕ НОВОСТИ: МИНИ + БИГ

# %%
news_table = news_mini_table.append(news_big_table, ignore_index=True)

# %%
print(f"ВСЕГО новостей: {len(news_table)}")
news_table
# Out:
# ВСЕГО новостей: 142
#                                                   Name  \
# 0    Отдыхающие с риском для жизни спасли самую быс...
# 1    Итальянский чемпион ОИ назвал позорным отстран...
# 2    Названы главные критерии выбора хорошего пласт...
# 3    МВД отвергло обвинения лидера хакеров Lurk в п...
# 4    Пробка на мосту в Бразилии обернулась смертью ...
# 5    США предупреждали Украину о приближении крылат...
# 6    Пьяная российская пара забила до смерти подруг...
# 7      ЦБ разрешил юрлицам покупать иностранные бумаги
# 8    Блогерша сделала 14 татуировок на ноге за один...
# 9    Минобороны показало занятия по боевому слажива...
# 10   Джордж Клуни рассказал об «ужасной» ошибке в в...
# 11   Кремль высказался о письме из Дагестана об отс...
# 12   Южная Корея заявила о запуске КНДР двух ракет ...
# 13   Фьюри сообщил о продолжении переговоров по бою...
# 14           Открыт новый вид древнейших челюстных рыб
# 15   В России резко увеличилось количество одного т...
# 16   Отдыхавшая в Турции туристка поехала на экскур...
# 17   Евросоюз захотел оставить российских силовиков...
# 18   Германия заявила о подрыве «Северного потока» ...
# 19   В Кремле анонсировали подписание договоров о п...
# 20   Раскрыты новые подробности убийства Александра...
# 21   ЕC введет запрет на импорт стальной продукции ...
# 22        Раскрыты сроки вхождения ЛНР в состав России
# 23   14 человек пострадали при взрыве боеприпаса в ...
# 24   Власти ввели режим повышенной готовности из-за...
# 25         Собянин заявил об отзыве ошибочных повесток
# 26   Молдавия приготовилась к прекращению поставок ...
# 27   Путин заявил о планах террористов на пригранич...
# 28   Минфин Германии рассказал об энергетической во...
# 29   Россия захотела обратиться в Международный суд...
# 30            Молдавия создаст собственные запасы газа
# 31                    Цены на газ в Европе резко упали
# 32   Захарова предложила главе МИД Литвы заняться п...
# 33   Россия созовет срочное заседание Совбеза ООН и...
# 34   Россияне стали реже ходить в кино после объявл...
# 35   В МИД России заявили о готовности сотрудничать...
# 36   Россиянкам назвали способы визуально уменьшить...
# 37   Звезда «Сладкой жизни» рассказала о жизни в Си...
# 38   Россиянин попал в Европу через Норвегию и расс...
# 39   Осужденному за охоту Рашкину отказали в возвра...
# 40   Сообщение о дезертирских печатях для уехавших ...
# 41    Путин связал конфликт на Украине с развалом СССР
# 42   Путин заявил о готовности Запада поставить под...
# 43   РФС подготовит для футболистов бронь от частич...
# 44   Командир спецназа «Ахмат» дал совет мобилизова...
# 45   Названы сроки окончания утечки газа из «Северн...
# 46   На Украине предрекли появление нового «троянск...
# 47   Путин заявил о формировании более справедливог...
# 48   Кардиолог рассказал о преимуществе женщин пере...
# 49   Россияне начали скупать вставшие в пробку у Гр...
# 50                  Эксклюзив PlayStation выйдет на ПК
# 51   Девушка осталась с внешностью персонажа из Ang...
# 52   В Москве уклониста от мобилизации нашли с помо...
# 53   Крупный автопроизводитель создал машину из кар...
# 54         Плющенко высказался о частичной мобилизации
# 55   Определены победители специального конкурса пр...
# 56   Участника популярного шоу на ТНТ госпитализиро...
# 57   Анфиса Чехова пожаловалась на проблемы со здор...
# 58   Сообщение о явке меньше 1 процента в Запорожье...
# 59   Латвия собралась бороться с русскими фамилиями...
# 60   Названа выделенная на поддержку жителей Донбас...
# 61   В Херсонской области диверсанты взорвали опору...
# 62   Обвиняемый в серии убийств российских детей му...
# 63   Россия будет ждать усилий от ООН по снятию сан...
# 64   В Северной Осетии разъяснили правила доступа к...
# 65   Спасение девочки от вцепившегося в нее пса поп...
# 66   Певца Ар Келли обязали выплатить жертве 300 ты...
# 67   Композитор «Русалочки» ответил критикам темнок...
# 68   Европейская страна откажется от российского га...
# 69   Названы способы сделать лапшу быстрого пригото...
# 70   Женский наряд из КЧР представят на конференции...
# 71                Intel захотела «подружиться» с Apple
# 72   Вице-президент США заявила о «крепком альянсе ...
# 73   Модель из Мьянмы получила политическое убежище...
# 74   Стало известно о росте нагрузки на приюты для ...
# 75   В России утвердят алфавит коренного малочислен...
# 76   Россиянам назвали нюансы быстрой продажи ипоте...
# 77   Магазины Lego открылись в Москве под новой выв...
# 78   Назван срок устранения утечек на «Северном пот...
# 79   Двум краснодарским школам присвоили имена Геро...
# 80   Крупнейшая авиакомпания разрешила мужчинам-бор...
# 81   Власти приграничного региона России опровергли...
# 82   Пострадавшую из-за обстрела ВСУ Харьковской об...
# 83   В Латвии заявили об изменении отношений между ...
# 84   Председатель ПСБ принял участие в форуме «Росс...
# 85   Стало известно о состоянии пострадавших беженц...
# 86   Билборд с благодарностями Байдену появился в ц...
# 87   На конкурсах «Лидеры возрождения пояснили треб...
# 88   Директор Аллы Пугачевой прокомментировала ново...
# 89   Минобороны официально объявило задачу мобилизо...
# 90   Болезни сердца убивают россиян стремительнее, ...
# 91   «НАТО не тянет на роль жандарма» Что ждет мир ...
# 92   Россия и Украина обменялись пленными. Бойцов «...
# 93   Не рассчитали. Тысячи россиян решили временно ...
# 94   Что значат записи в военном билете: категории ...
# 95   В ДНР, ЛНР, Запорожской и Херсонской областях ...
# 96   Что ждет россиян во время частичной мобилизаци...
# 97   Путин объявил в России частичную мобилизацию. ...
# 98   «Матери я еще не звонил» Мобилизованные россия...
# 99   «Это была мясорубка! Камни в 300 тонн летали» ...
# 100  Стал известен порядок мобилизации в России. Ра...
# 101  Мобилизация, оскорбление чувств, КГБ и ЛГБТ: к...
# 102  «Унижение преследует тебя везде» Как живет чел...
# 103  Украинский де Голль. Командующий ВСУ Залужный ...
# 104  «Телефон сел, света нет, а кругом лабиринт» Чт...
# 105  Пятый элемент. Российский Су-57 — лучший в мир...
# 106  «К заключениям из частных клиник относятся кра...
# 107  Мимикрия: одни машины в обличье других Бюджетн...
# 108  «Вернулись домой с лампой Алладина в руках» Ка...
# 109  «Россиянам было не до красоты» Какую обувь нос...
# 110  Представлен гибридный суперкроссовер BMW XM Вс...
# 111  Прекрасное безумие: история «четырехколесных и...
# 112  «Я никогда себя не ругаю» Известная телеведуща...
# 113  Новый Ford Super Duty впечатлил рекордным дизе...
# 114  Great Wall Poer: вот зачем нужен пикап! Как пр...
# 115  «Присоединенный балкон вам никогда не узаконят...
# 116  Суперкары для бездорожья Эти автомобили не сбр...
# 117  «В потертую шапку летели монеты» Жизнь и нравы...
# 118  Сумасшедшие грузовики для гонок DAF, Scania, 2...
# 119  «Москва — не пацанский город» Где гуляют, что ...
# 120  Автомобили, которые заменят электрокарами Эти ...
# 121  Знаковые концепты Bertone: часть 2 Минивэн Lam...
# 122  «Люди грубоватые, но достойные» Что думают о м...
# 123  «С криминалом здесь получше, чем в центре» Как...
# 124  Десять ярких концепт-каров Bertone К 110-летию...
# 125  От бандитов до режиссеров Как печально известн...
# 126  «Барбершоп — это мужская территория» Московски...
# 127  В ДНР, ЛНР, Запорожской и Херсонской областях ...
# 128  «Злость прибавила сил и смелости нашим бойцам»...
# 129  ЛГБТитан. Умер Борис Моисеев, главный эстрадны...
# 130  «Действительно большая дыра» Газопровод «Север...
# 131  «Мам, мне страшно — нас расстреливают» Трагеди...
# 132  Повестка, отсрочка и неявка: что и как делать,...
# 133  «Спасти человечество от ада» О чем не договори...
# 134  Здоровье в смартфоне. Как цифровые медицинские...
# 135  «Мне больше не нужны насилие и обнаженка» Режи...
# 136  «Кошмар начался на второй день» Истории турист...
# 137  Беспрецедентные разрушения на «Северном потоке...
# 138  Мужчина с двумя пистолетами напал на школу в И...
# 139  «Это наш позор!» После гибели 22-летней девушк...
# 140  «Жаль, что мир этого не видит» Валиева, Трусов...
# 141  Что значат записи в военном билете: категории ...
#
#                                                   Link  \
# 0        https://lenta.ru/news/2022/09/29/sharkrescue/
# 1           https://lenta.ru/news/2022/09/29/milanoli/
# 2       https://lenta.ru/news/2022/09/29/vyborhirurga/
# 3         https://lenta.ru/news/2022/09/29/oprovergli/
# 4              https://lenta.ru/news/2022/09/29/31435/
# 5           https://lenta.ru/news/2022/09/29/krylatye/
# 6            https://lenta.ru/news/2022/09/29/parasud/
# 7        https://lenta.ru/news/2022/09/29/bezogranich/
# 8             https://lenta.ru/news/2022/09/29/tattoo/
# 9          https://lenta.ru/news/2022/09/29/zanyatiya/
# 10        https://lenta.ru/news/2022/09/29/clooneydad/
# 11            https://lenta.ru/news/2022/09/29/letter/
# 12          https://lenta.ru/news/2022/09/29/koreaaaa/
# 13              https://lenta.ru/news/2022/09/29/fury/
# 14             https://lenta.ru/news/2022/09/29/shark/
# 15       https://lenta.ru/news/2022/09/29/more_studii/
# 16     https://lenta.ru/news/2022/09/29/disabled_life/
# 17            https://lenta.ru/news/2022/09/29/shokkk/
# 18   https://lenta.ru/news/2022/09/29/northstreamge...
# 19    https://lenta.ru/news/2022/09/29/dogovor_peskov/
# 20       https://lenta.ru/news/2022/09/29/zaharchenko/
# 21              https://lenta.ru/news/2022/09/29/stal/
# 22           https://lenta.ru/news/2022/09/29/nedelya/
# 23        https://lenta.ru/news/2022/09/28/vryv_belgr/
# 24               https://lenta.ru/news/2022/09/28/ubv/
# 25            https://lenta.ru/news/2022/09/28/povest/
# 26             https://lenta.ru/news/2022/09/29/prekr/
# 27         https://lenta.ru/news/2022/09/29/afg_putin/
# 28    https://lenta.ru/news/2022/09/29/komuvoynaakomu/
# 29            https://lenta.ru/news/2022/09/29/un_sud/
# 30              https://lenta.ru/news/2022/09/29/mold/
# 31          https://lenta.ru/news/2022/09/29/ttf_down/
# 32        https://lenta.ru/news/2022/09/29/zakh_litva/
# 33              https://lenta.ru/news/2022/09/29/4647/
# 34         https://lenta.ru/news/2022/09/29/kinoteatr/
# 35       https://lenta.ru/news/2022/09/29/italyyyyyys/
# 36             https://lenta.ru/news/2022/09/29/waist/
# 37      https://lenta.ru/news/2022/09/29/novosib_zima/
# 38        https://lenta.ru/news/2022/09/29/norway_way/
# 39          https://lenta.ru/news/2022/09/29/rashkinn/
# 40        https://lenta.ru/news/2022/09/29/fake_deser/
# 41              https://lenta.ru/news/2022/09/29/ussr/
# 42              https://lenta.ru/news/2022/09/29/zapp/
# 43               https://lenta.ru/news/2022/09/29/rfs/
# 44            https://lenta.ru/news/2022/09/29/akhmat/
# 45         https://lenta.ru/news/2022/09/29/utechstop/
# 46               https://lenta.ru/news/2022/09/29/kon/
# 47              https://lenta.ru/news/2022/09/29/mirr/
# 48       https://lenta.ru/news/2022/09/29/womensheart/
# 49          https://lenta.ru/news/2022/09/29/larsssss/
# 50           https://lenta.ru/news/2022/09/29/sackboy/
# 51     https://lenta.ru/news/2022/09/29/eyebrows-done/
# 52             https://lenta.ru/news/2022/09/29/padik/
# 53     https://lenta.ru/news/2022/09/29/cardboard_car/
# 54       https://lenta.ru/news/2022/09/29/plushchenko/
# 55            https://lenta.ru/news/2022/09/29/prgrnt/
# 56            https://lenta.ru/news/2022/09/29/africa/
# 57   https://lenta.ruhttps://moslenta.ru/news/city/...
# 58            https://lenta.ru/news/2022/09/29/1yavka/
# 59     https://lenta.ru/news/2022/09/29/latviya_opyat/
# 60             https://lenta.ru/news/2022/09/29/summa/
# 61           https://lenta.ru/news/2022/09/29/div_lep/
# 62         https://lenta.ru/news/2022/09/29/serijasud/
# 63   https://lenta.ru/news/2022/09/29/rusuausanctions/
# 64           https://lenta.ru/news/2022/09/29/pynktyy/
# 65         https://lenta.ru/news/2022/09/29/angry_dog/
# 66            https://lenta.ru/news/2022/09/29/rkelly/
# 67        https://lenta.ru/news/2022/09/29/compositor/
# 68            https://lenta.ru/news/2022/09/29/rusgaz/
# 69            https://lenta.ru/news/2022/09/29/lapsha/
# 70            https://lenta.ru/news/2022/09/29/naryad/
# 71       https://lenta.ru/news/2022/09/29/intel_apple/
# 72            https://lenta.ru/news/2022/09/29/harris/
# 73     https://lenta.ru/news/2022/09/29/myanmar-model/
# 74              https://lenta.ru/news/2022/09/29/pets/
# 75              https://lenta.ru/news/2022/09/29/saam/
# 76          https://lenta.ru/news/2022/09/29/prodadim/
# 77   https://lenta.ruhttps://moslenta.ru/news/city/...
# 78     https://lenta.ru/news/2022/09/29/ustranitutech/
# 79             https://lenta.ru/news/2022/09/29/kuban/
# 80   https://lenta.ru/news/2022/09/29/virgin_airlines/
# 81          https://lenta.ru/news/2022/09/29/oproverg/
# 82          https://lenta.ru/news/2022/09/29/devochka/
# 83        https://lenta.ru/news/2022/09/29/rus_hockey/
# 84        https://lenta.ru/news/2022/09/29/forumsport/
# 85     https://lenta.ru/news/2022/09/29/roditelydetey/
# 86         https://lenta.ru/news/2022/09/29/biden_thx/
# 87             https://lenta.ru/news/2022/09/29/trbvn/
# 88     https://lenta.ru/news/2022/09/29/director_alla/
# 89       https://lenta.ru/news/2022/09/29/mobi_oboron/
# 90     https://lenta.ru/articles/2022/09/29/heart_day/
# 91      https://lenta.ru/articles/2022/09/29/chadayev/
# 92       https://lenta.ru/brief/2022/09/22/plen_obmen/
# 93        https://lenta.ru/articles/2022/09/23/zagran/
# 94     https://lenta.ru/articles/2022/09/24/voenbilet/
# 95             https://lenta.ru/brief/2022/09/20/refs/
# 96          https://lenta.ru/articles/2022/09/21/ukaz/
# 97            https://lenta.ru/brief/2022/09/21/putin/
# 98    https://lenta.ru/articles/2022/09/23/prizyvniki/
# 99      https://lenta.ru/articles/2022/09/20/karmadon/
# 100        https://lenta.ru/brief/2022/09/22/poryadok/
# 101      https://lenta.ru/articles/2022/09/29/pelevin/
# 102  https://lenta.ru/articles/2022/09/29/starwarskid/
# 103      https://lenta.ru/articles/2022/09/28/borotba/
# 104        https://lenta.ru/articles/2022/09/29/caves/
# 105         https://lenta.ru/articles/2022/09/28/su57/
# 106  https://lenta.ru/articles/2022/09/28/mobilizat...
# 107  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 108  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 109  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 110  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 111  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 112  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 113  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 114  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 115  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 116  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 117  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 118  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 119  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 120  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 121  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 122  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 123  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 124  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 125  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 126  https://lenta.ruhttps://lenta.ru/extlink/2022/...
# 127     https://lenta.ru/brief/2022/09/27/referendums/
# 128      https://lenta.ru/articles/2022/09/28/belgrad/
# 129  https://lenta.ru/articles/2022/09/27/boris_moi...
# 130  https://lenta.ru/articles/2022/09/27/nord_stre...
# 131    https://lenta.ru/articles/2022/09/27/izhschool/
# 132  https://lenta.ru/articles/2022/09/27/povestkam...
# 133           https://lenta.ru/articles/2022/09/27/un/
# 134  https://lenta.ru/articles/2022/09/27/for_patie...
# 135  https://lenta.ru/articles/2022/09/27/parkchanw...
# 136  https://lenta.ru/articles/2022/09/27/couchsurf...
# 137  https://lenta.ru/extlink/2022/09/27/sevpo_ext/...
# 138          https://lenta.ru/brief/2022/09/26/school/
# 139  https://lenta.ru/articles/2022/09/26/mahsa_amini/
# 140    https://lenta.ru/articles/2022/09/26/fs_russia/
# 141    https://lenta.ru/articles/2022/09/24/voenbilet/
#
#                         Date Source N_Type
# 0           2022-09-29;18:36    NaN   mini
# 1           2022-09-29;18:36    NaN   mini
# 2           2022-09-29;18:35    NaN   mini
# 3           2022-09-29;18:35    NaN   mini
# 4           2022-09-29;18:29    NaN   mini
# 5           2022-09-29;18:28    NaN   mini
# 6           2022-09-29;18:28    NaN   mini
# 7           2022-09-29;18:23    NaN   mini
# 8           2022-09-29;18:22    NaN   mini
# 9           2022-09-29;18:21    NaN   mini
# 10          2022-09-29;18:20    NaN   mini
# 11          2022-09-29;17:54    NaN   mini
# 12          2022-09-29;18:19    NaN   mini
# 13          2022-09-29;18:17    NaN   mini
# 14          2022-09-29;18:16    NaN   mini
# 15          2022-09-29;18:16    NaN   mini
# 16          2022-09-29;18:14    NaN   mini
# 17          2022-09-29;18:13    NaN   mini
# 18          2022-09-29;18:43    NaN   mini
# 19          2022-09-29;18:43    NaN   mini
# 20          2022-09-29;18:43    NaN   mini
# 21          2022-09-29;18:43    NaN   mini
# 22          2022-09-29;18:43    NaN   mini
# 23          2022-09-29;18:43    NaN   mini
# 24          2022-09-29;18:43    NaN   mini
# 25          2022-09-29;18:43    NaN   mini
# 26          2022-09-29;18:12    NaN   mini
# 27          2022-09-29;18:09    NaN   mini
# 28          2022-09-29;18:08    NaN   mini
# 29          2022-09-29;18:08    NaN   mini
# 30          2022-09-29;18:06    NaN   mini
# 31          2022-09-29;18:04    NaN   mini
# 32          2022-09-29;18:00    NaN   mini
# 33          2022-09-29;17:58    NaN   mini
# 34          2022-09-29;17:57    NaN   mini
# 35          2022-09-29;17:56    NaN   mini
# 36          2022-09-29;17:54    NaN   mini
# 37          2022-09-29;17:51    NaN   mini
# 38          2022-09-29;17:51    NaN   mini
# 39          2022-09-29;17:50    NaN   mini
# 40          2022-09-29;17:45    NaN   mini
# 41          2022-09-29;17:44    NaN   mini
# 42          2022-09-29;17:42    NaN   mini
# 43          2022-09-29;17:42    NaN   mini
# 44          2022-09-29;17:42    NaN   mini
# 45          2022-09-29;17:37    NaN   mini
# 46          2022-09-29;17:37    NaN   mini
# 47          2022-09-29;17:36    NaN   mini
# 48          2022-09-29;17:35    NaN   mini
# 49          2022-09-29;17:34    NaN   mini
# 50          2022-09-29;17:34    NaN   mini
# 51          2022-09-29;17:27    NaN   mini
# 52          2022-09-29;17:26    NaN   mini
# 53          2022-09-29;17:24    NaN   mini
# 54          2022-09-29;17:23    NaN   mini
# 55          2022-09-29;17:22    NaN   mini
# 56          2022-09-29;17:21    NaN   mini
# 57          2022-09-29;17:19    NaN   mini
# 58          2022-09-29;17:19    NaN   mini
# 59          2022-09-29;17:16    NaN   mini
# 60          2022-09-29;17:12    NaN   mini
# 61          2022-09-29;17:10    NaN   mini
# 62          2022-09-29;17:08    NaN   mini
# 63          2022-09-29;17:08    NaN   mini
# 64          2022-09-29;17:07    NaN   mini
# 65          2022-09-29;17:04    NaN   mini
# 66          2022-09-29;17:01    NaN   mini
# 67          2022-09-29;17:01    NaN   mini
# 68          2022-09-29;16:58    NaN   mini
# 69          2022-09-29;16:57    NaN   mini
# 70          2022-09-29;16:57    NaN   mini
# 71          2022-09-29;16:55    NaN   mini
# 72          2022-09-29;16:54    NaN   mini
# 73          2022-09-29;16:53    NaN   mini
# 74          2022-09-29;16:52    NaN   mini
# 75          2022-09-29;16:51    NaN   mini
# 76          2022-09-29;16:49    NaN   mini
# 77          2022-09-29;16:47    NaN   mini
# 78          2022-09-29;16:45    NaN   mini
# 79          2022-09-29;16:44    NaN   mini
# 80          2022-09-29;16:43    NaN   mini
# 81          2022-09-29;16:41    NaN   mini
# 82          2022-09-29;16:40    NaN   mini
# 83          2022-09-29;16:40    NaN   mini
# 84          2022-09-29;16:39    NaN   mini
# 85          2022-09-29;16:38    NaN   mini
# 86          2022-09-29;16:36    NaN   mini
# 87          2022-09-29;16:35    NaN   mini
# 88          2022-09-29;16:34    NaN   mini
# 89                     17:37    NaN    BIG
# 90                     00:01    NaN    BIG
# 91                     08:01    NaN    BIG
# 92   16:49, 22 сентября 2022    NaN    BIG
# 93   00:01, 23 сентября 2022    NaN    BIG
# 94   00:01, 24 сентября 2022    NaN    BIG
# 95   14:13, 20 сентября 2022    NaN    BIG
# 96   19:45, 21 сентября 2022    NaN    BIG
# 97   09:56, 21 сентября 2022    NaN    BIG
# 98   18:44, 23 сентября 2022    NaN    BIG
# 99   00:01, 20 сентября 2022    NaN    BIG
# 100  19:38, 22 сентября 2022    NaN    BIG
# 101                    00:01    NaN    BIG
# 102                    00:01    NaN    BIG
# 103  00:01, 28 сентября 2022    NaN    BIG
# 104                    00:01    NaN    BIG
# 105  00:01, 28 сентября 2022    NaN    BIG
# 106  00:01, 28 сентября 2022    NaN    BIG
# 107                    08:24    NaN    BIG
# 108                    00:05    NaN    BIG
# 109  00:05, 28 сентября 2022    NaN    BIG
# 110  08:48, 28 сентября 2022    NaN    BIG
# 111  09:27, 27 сентября 2022    NaN    BIG
# 112  00:05, 27 сентября 2022    NaN    BIG
# 113  08:48, 28 сентября 2022    NaN    BIG
# 114  09:21, 26 сентября 2022    NaN    BIG
# 115  00:05, 26 сентября 2022    NaN    BIG
# 116  08:24, 25 сентября 2022    NaN    BIG
# 117  00:09, 25 сентября 2022    NaN    BIG
# 118  07:42, 24 сентября 2022    NaN    BIG
# 119  00:20, 24 сентября 2022    NaN    BIG
# 120  07:40, 23 сентября 2022    NaN    BIG
# 121  08:32, 23 сентября 2022    NaN    BIG
# 122  00:05, 23 сентября 2022    NaN    BIG
# 123  00:27, 22 сентября 2022    NaN    BIG
# 124  07:50, 22 сентября 2022    NaN    BIG
# 125  12:16, 21 сентября 2022    NaN    BIG
# 126  00:06, 21 сентября 2022    NaN    BIG
# 127  19:40, 27 сентября 2022    NaN    BIG
# 128  00:01, 28 сентября 2022    NaN    BIG
# 129  19:27, 27 сентября 2022    NaN    BIG
# 130  19:02, 27 сентября 2022    NaN    BIG
# 131  00:07, 27 сентября 2022    NaN    BIG
# 132  00:01, 27 сентября 2022    NaN    BIG
# 133  00:01, 27 сентября 2022    NaN    BIG
# 134  10:59, 27 сентября 2022    NaN    BIG
# 135  00:02, 27 сентября 2022    NaN    BIG
# 136  00:02, 27 сентября 2022    NaN    BIG
# 137  12:37, 27 сентября 2022    NaN    BIG
# 138  12:50, 26 сентября 2022    NaN    BIG
# 139  00:01, 26 сентября 2022    NaN    BIG
# 140  00:44, 26 сентября 2022    NaN    BIG
# 141  00:01, 24 сентября 2022    NaN    BIG

# %% [markdown]
# <!--  -->

# %% [markdown]
# __P.S.__
#
# Не удалось распарсить значение атрибута `xlink:href` тега `use` — как только не пытался при помощи `xpath`...
#
# __КАК ЭТО СДЕЛАТЬ ПРИ ПОМОЩИ `XPATH`?__

# %% [markdown]
# <!--  -->
