# %% [markdown]
# `GB` BigData / [Олег Гладкий](https://gb.ru/users/3837199) // домашнее задание

# %% [markdown]
# `262698` __Методы сбора и обработки данных из сети Интернет__:  `03`. Парсинг даных: HTML, __Beautiful-Soap__

# %% [markdown]
# ## Задание 1. Beautiful-Soap. hh.ru

# %% [markdown]
# Собрать информацию о вакансиях на вводимую должность с сайтов `hh.ru` и/или `Superjob` и/или `работа.ру`. Приложение должно анализировать несколько страниц сайта. Получившийся список должен содержать в себе минимум:
# * Наименование вакансии.
# * Предлагаемую зарплату (дополнительно: разносим в три поля: минимальная и максимальная и валюта. цифры преобразуем к цифрам).
# * Ссылку на саму вакансию.
# * Сайт, откуда собрана вакансия.
#
#
# По желанию можно добавить ещё параметры вакансии (например, работодателя и расположение). Структура должна быть одинаковая для вакансий со всех сайтов. Общий результат можно вывести с помощью `dataFrame` через `pandas`, сохранить в `json`, либо `csv`.
#
# Минимум — один сайт, МАКСИМУМ — все два...

# %%
from bs4 import BeautifulSoup as bs
import requests

import time
import datetime
import pandas as pd
import numpy as np
import json
import math

import platform  # информация о системе 

from pprint import pprint 
# import re
# from lxml import html  # xpath

# %% [markdown]
# ### Функции

# %% [markdown]
# __Money__, фунукция `get_money()`, возвращает словарь разобранных их строки значений зарплаты

# %%
def get_maney(money_range_str:str="") ->dict:
    
    ''' Выделим цифровые значения зарплаты из строки '''
    
    pay = {'min': 0, 'max': 0, 'curr': ''}
    
    if not money_range_str:
        return pay
    
    # Специальные пробельные символы необходимо "схлопнуть"
    
    special_space_symbols = {
        "NARROW_NO_BREAK_SPACE": "\u202f", 
        "NO_BREAK_SPACE": "\u00a0",
        "TAB":"\t",
    }

    for key, space_code in special_space_symbols.items():
        money_range_str = money_range_str.replace(space_code, "")

    # Анализируем: 
    
    money_words = money_range_str.split(" ")  # Раделим строку на слова
    i = 0
    while money_words:
        i += 1
        if i  > 10:
            print("Выход из бесконечного цикла")
            break
      
        if not money_words[-1].isdigit():
            pay['curr'] = money_words[-1]
            money_words.pop(-1)
            continue

        if money_words[0].upper() == "от".upper() or money_words[0].upper() == "from".upper():
            pay['min'] = int(money_words[1])
            money_words.pop(1)
            money_words.pop(0)
            continue

        if money_words[0].upper() == "до".upper():
            pay['max'] = int(money_words[1])
            money_words.pop(1)
            money_words.pop(0)
            continue
            
        if money_words[0].isdigit():
            pay['min'] = int(money_words[0])
            money_words.pop(0)
            continue
            
        if money_words[0] == "-" or money_words[0] == "–" or money_words[0] == "—" or money_words[0] == "--":
            pay['max'] = int(money_words[1])
            money_words.pop(1)
            money_words.pop(0)
    else:
        if not pay['min']:
            pay['min'] = 0
        if not pay['max']:
            pay['max'] = pay['min']
        pass
          
    return pay

# %% [markdown]
# __Soup__, фунукция `get_soup()`, возвращает струтуру `bs4.BeautifulSoup`

# %%
def get_soup(url:str=None, headers:str=None, params:str=None) -> bs("", 'html.parser'):
    
    if not url: return None  # проверка...
    
    response = requests.get(url=url, headers=headers, params=params)

    if not response.ok:
        print(response.status_code, response.url)
        return None
    
    if response.headers['Content-Type'] != 'text/html; charset=utf-8':
        print(response.headers['Content-Type'])
        return None
    
    soup = bs(response.text, 'html.parser')
    
    return soup

# %% [markdown]
# __Вакансии__: функция `get_vacancies_hh_parser` парсит вакансии с сайта hh.ru из полученной струтуры `soup`

# %%
def get_vacancies_hh_parser(soup="") -> list: 
    
    ''' запрос вакансий с сайта hh.ru '''
    
    if not soup: return None
    
    cards = soup.find_all(name='div', attrs={'class': ['serp-item'], 'data-qa': True})
    
    if len(cards) == 0:
        return None
    
    vacancies = list()
    
    for i, card in enumerate(cards, start=1): 
        name = card.find(name='a', attrs={'class': 'serp-item__title'}).text
        link = card.find(name='a', attrs={'class': 'serp-item__title'}).get('href').split('?')[0]
       
        try:
            comp = card.find(name='a', attrs={'class': ['bloko-link', 'bloko-link_kind-tertiary'], 'data-qa': 'vacancy-serp__vacancy-employer'}).text
            
        except:
            comp = "__AttributeError__"
            print(f"AttributeError, item {i}")
            #comt = card.find(name='div', attrs={'class': 'vacancy-serp-item__meta-info-company'}.text)
            
        maney = card.find(name='span', attrs={'data-qa': 'vacancy-serp__vacancy-compensation'})
        maney = maney.get_text(strip=False) if maney else None 
        maney = get_maney(maney) # разбор строки в список значений словаря...
        
        
        vacancy = {'Name': name, 'Company': comp, 'Link': link, 'Date': request_date, 'Source': url, \
                   'Maney_min': maney['min'], 'Maney_max': maney['max'], 'Maney_curr': maney['curr']}
        
        vacancies.append(vacancy)  # type: list
        
    return vacancies

# %% [markdown]
# __Страницы__: функция `get_pages()` парсит количество страниц по данному запросу из полученной струтуры `soup`.

# %%
def get_pages(soup=None, item_on_page=None) ->int:
    
    '''Определяем количество страниц ответа сервера'''
    
    if not soup or not item_on_page: 
        print("get_pages() -- пустой вызов")
        return None
    
    items = soup.find(name='h1', attrs={'class': ['bloko-header-section-3'], 'data-qa': ['bloko-header-3']}).text
    items = get_maney(items)['min']

    pages = int(math.ceil(items/item_on_page))
    
    return pages

# %% [markdown]
# ### Параметры доступа к сайту

# %%
if platform.system() == 'Windows':
    win_ver = platform.release()
    if win_ver == '7': # Windows 7 User-Agent
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}
    elif win_ver == '10':  # Windows 10 User-Agent        
        headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',}
else:
    print("ВНИМАНИЕ! ЮРЕЗ-АГЕНТ НЕ СООТВЕТСТВУЕТ СИСТЕМЕ")
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}

item_on_page = 20
url = 'https://hh.ru/search/vacancy/'
params = {
    'area':1,
    'clusters':'true',
    'enable_snippets':'true',
    'items_on_page':item_on_page,
    'ored_clusters':'true',
    'search_field':'description',
    'text':'python',
    'order_by':'publication_time',
    'hhtmFrom':'vacancy_search_list',
}

# %% [markdown]
# ## Поехали!

# %% [markdown]
# Запрашиваем странички и парсим их...

# %%
# %%time
sleep_interval = 2  # задержка между запросами
request_date = str(datetime.date.today())
request_time = str(datetime.datetime.now().strftime("%H:%M"))

vacancies_dict = dict()
vacancies = list()
soup = ""
pages = 1
page = 0

while page < pages: 

    params['page'] = page
    soup = get_soup(url=url, headers=headers, params=params)

    if soup:
        vacancies = vacancies + get_vacancies_hh_parser(soup)
        time.sleep(sleep_interval)
    else:
        print(f"Страницы выборки закончились, всего получено и обработано {page} страниц.")
        break

    if page < 1:
        pages = get_pages(soup=soup, item_on_page=item_on_page)
        pass
        
    print(f"Страница {page+1} обработана успешно, всего страниц {pages}")
    page += 1

else:
    print(f"Получено {len(vacancies)} вакансий")    

pass
# Out:
# Страница 1 обработана успешно, всего страниц 220
# Страница 2 обработана успешно, всего страниц 220
# Страница 3 обработана успешно, всего страниц 220
# Страница 4 обработана успешно, всего страниц 220
# Страница 5 обработана успешно, всего страниц 220
# Страница 6 обработана успешно, всего страниц 220
# Страница 7 обработана успешно, всего страниц 220
# Страница 8 обработана успешно, всего страниц 220
# Страница 9 обработана успешно, всего страниц 220
# Страница 10 обработана успешно, всего страниц 220
# Страница 11 обработана успешно, всего страниц 220
# Страница 12 обработана успешно, всего страниц 220
# Страница 13 обработана успешно, всего страниц 220
# Страница 14 обработана успешно, всего страниц 220
# Страница 15 обработана успешно, всего страниц 220
# Страница 16 обработана успешно, всего страниц 220
# Страница 17 обработана успешно, всего страниц 220
# Страница 18 обработана успешно, всего страниц 220
# Страница 19 обработана успешно, всего страниц 220
# Страница 20 обработана успешно, всего страниц 220
# Страница 21 обработана успешно, всего страниц 220
# Страница 22 обработана успешно, всего страниц 220
# Страница 23 обработана успешно, всего страниц 220
# Страница 24 обработана успешно, всего страниц 220
# Страница 25 обработана успешно, всего страниц 220
# Страница 26 обработана успешно, всего страниц 220
# Страница 27 обработана успешно, всего страниц 220
# Страница 28 обработана успешно, всего страниц 220
# Страница 29 обработана успешно, всего страниц 220
# Страница 30 обработана успешно, всего страниц 220
# Страница 31 обработана успешно, всего страниц 220
# Страница 32 обработана успешно, всего страниц 220
# Страница 33 обработана успешно, всего страниц 220
# Страница 34 обработана успешно, всего страниц 220
# Страница 35 обработана успешно, всего страниц 220
# Страница 36 обработана успешно, всего страниц 220
# Страница 37 обработана успешно, всего страниц 220
# Страница 38 обработана успешно, всего страниц 220
# Страница 39 обработана успешно, всего страниц 220
# Страница 40 обработана успешно, всего страниц 220
# Страница 41 обработана успешно, всего страниц 220
# Страница 42 обработана успешно, всего страниц 220
# Страница 43 обработана успешно, всего страниц 220
# Страница 44 обработана успешно, всего страниц 220
# Страница 45 обработана успешно, всего страниц 220
# Страница 46 обработана успешно, всего страниц 220
# Страница 47 обработана успешно, всего страниц 220
# Страница 48 обработана успешно, всего страниц 220
# Страница 49 обработана успешно, всего страниц 220
# Страница 50 обработана успешно, всего страниц 220
# Страница 51 обработана успешно, всего страниц 220
# Страница 52 обработана успешно, всего страниц 220
# Страница 53 обработана успешно, всего страниц 220
# Страница 54 обработана успешно, всего страниц 220
# Страница 55 обработана успешно, всего страниц 220
# Страница 56 обработана успешно, всего страниц 220
# Страница 57 обработана успешно, всего страниц 220
# Страница 58 обработана успешно, всего страниц 220
# Страница 59 обработана успешно, всего страниц 220
# Страница 60 обработана успешно, всего страниц 220
# Страница 61 обработана успешно, всего страниц 220
# Страница 62 обработана успешно, всего страниц 220
# Страница 63 обработана успешно, всего страниц 220
# Страница 64 обработана успешно, всего страниц 220
# Страница 65 обработана успешно, всего страниц 220
# Страница 66 обработана успешно, всего страниц 220
# Страница 67 обработана успешно, всего страниц 220
# Страница 68 обработана успешно, всего страниц 220
# Страница 69 обработана успешно, всего страниц 220
# Страница 70 обработана успешно, всего страниц 220
# Страница 71 обработана успешно, всего страниц 220
# Страница 72 обработана успешно, всего страниц 220
# Страница 73 обработана успешно, всего страниц 220
# Страница 74 обработана успешно, всего страниц 220
# Страница 75 обработана успешно, всего страниц 220
# Страница 76 обработана успешно, всего страниц 220
# Страница 77 обработана успешно, всего страниц 220
# Страница 78 обработана успешно, всего страниц 220
# Страница 79 обработана успешно, всего страниц 220
# Страница 80 обработана успешно, всего страниц 220
# Страница 81 обработана успешно, всего страниц 220
# AttributeError, item 18
# Страница 82 обработана успешно, всего страниц 220
# Страница 83 обработана успешно, всего страниц 220
# Страница 84 обработана успешно, всего страниц 220
# Страница 85 обработана успешно, всего страниц 220
# Страница 86 обработана успешно, всего страниц 220
# Страница 87 обработана успешно, всего страниц 220
# Страница 88 обработана успешно, всего страниц 220
# Страница 89 обработана успешно, всего страниц 220
# Страница 90 обработана успешно, всего страниц 220
# Страница 91 обработана успешно, всего страниц 220
# Страница 92 обработана успешно, всего страниц 220
# Страница 93 обработана успешно, всего страниц 220
# Страница 94 обработана успешно, всего страниц 220
# Страница 95 обработана успешно, всего страниц 220
# Страница 96 обработана успешно, всего страниц 220
# Страница 97 обработана успешно, всего страниц 220
# Страница 98 обработана успешно, всего страниц 220
# Страница 99 обработана успешно, всего страниц 220
# Страница 100 обработана успешно, всего страниц 220
# 404 https://nahabino.hh.ru/search/vacancy?area=1&clusters=true&enable_snippets=true&items_on_page=20&ored_clusters=true&search_field=description&text=python&order_by=publication_time&hhtmFrom=vacancy_search_list&page=100
# Страницы выборки закончились, всего получено и обработано 100 страниц.
# Wall time: 4min 50s

# %% [markdown]
# __Запись__ данных на диск
# Записываем все полученные данные в файл `03_hw_HTML_Beautiful-Soap_VACANCIES` на диск в `json`-формате.

# %%
# Записываем результат на диск (пишем сразу всё, а не частично)

with open('03_hw_HTML_Beautiful-Soap_VACANCIES.json', 'w') as out_f:
    json.dump(vacancies, out_f)

# %% [markdown]
# __Вид__ в формате таблицы `DataFrame`

# %%
vacancies_DF = pd.DataFrame()
vacancies_DF = vacancies_DF.append(vacancies, ignore_index=True)
print(f"Размер таблицы DataFrame: {vacancies_DF.shape}, Строк: {len(vacancies_DF)}")
vacancies_DF
# Out:
# Размер таблицы DataFrame: (2000, 8), Строк: 2000
#                                                    Name  \
# 0                                 Data Quality Engineer
# 1                            Middle / Senior QA инженер
# 2             Middle / Senior QA в команду безопасности
# 3     Разработчик встраиваемого/бортового ПО (C++) (...
# 4                   Разработчик C++ (релокация в Dubai)
# ...                                                 ...
# 1995  Ведущий инженер по инфраструктуре (Цифровые по...
# 1996            Инженер-программист (Software Engineer)
# 1997                     Коммерческий аналитик (senior)
# 1998         Инженер киберугроз / Cyber Threat Engineer
# 1999       BI-аналитик (Департамент управления данными)
#
#                                     Company  \
# 0                       ООО HeadHunter:: IT
# 1                        ООО HeadHunter::QA
# 2                        ООО HeadHunter::QA
# 3                                 R2CMarket
# 4                                 R2CMarket
# ...                                     ...
# 1995                               Сбер. IT
# 1996    ООО Специальные технологии контроля
# 1997                             Делимобиль
# 1998                               CtrlHack
# 1999  Центральный банк Российской Федерации
#
#                                          Link        Date  \
# 0     https://nahabino.hh.ru/vacancy/67932769  2022-10-09
# 1     https://nahabino.hh.ru/vacancy/47759634  2022-10-09
# 2     https://nahabino.hh.ru/vacancy/47892571  2022-10-09
# 3     https://nahabino.hh.ru/vacancy/70893224  2022-10-09
# 4     https://nahabino.hh.ru/vacancy/70893089  2022-10-09
# ...                                       ...         ...
# 1995  https://nahabino.hh.ru/vacancy/70669562  2022-10-09
# 1996  https://nahabino.hh.ru/vacancy/69635375  2022-10-09
# 1997  https://nahabino.hh.ru/vacancy/66877862  2022-10-09
# 1998  https://nahabino.hh.ru/vacancy/70668928  2022-10-09
# 1999  https://nahabino.hh.ru/vacancy/70668423  2022-10-09
#
#                              Source  Maney_min  Maney_max Maney_curr
# 0     https://hh.ru/search/vacancy/          0          0
# 1     https://hh.ru/search/vacancy/     200000     200000       руб.
# 2     https://hh.ru/search/vacancy/     200000     200000       руб.
# 3     https://hh.ru/search/vacancy/       4000       6000        USD
# 4     https://hh.ru/search/vacancy/       6000       8000        USD
# ...                             ...        ...        ...        ...
# 1995  https://hh.ru/search/vacancy/          0          0
# 1996  https://hh.ru/search/vacancy/     180000     180000       руб.
# 1997  https://hh.ru/search/vacancy/          0          0
# 1998  https://hh.ru/search/vacancy/          0          0
# 1999  https://hh.ru/search/vacancy/          0          0
#
# [2000 rows x 8 columns]

# %% [markdown]
# <!--  -->

# %% [markdown]
# <!--  -->

# %% [markdown]
# <!--  -->

# %% [markdown]
# __P.S.__

# %% [markdown]
# * Ошибку получения атрибута `text` для названия компании `comp` победить не удалось — отложил на будущее. Но в том месте, где это происходило встречались какие-то комментарии...
# * Почему-то более 100 страниц сайт `hh.ru` не отдаёт...

# %% [markdown]
# <!--  -->

# %% [markdown]
# ZIP of code...

# %%
# %%time
# инициализируем выходную таблицу
# vacancies = pd.DataFrame( \
#     columns=['Name', 'Company', 'Link', 'Date', 'Source', 'Maney_min', 'Maney_max', 'Maney_curr'], \
#     index=[])
# Out:
# Wall time: 0 ns
